-- %%
CREATE TABLE IF NOT EXISTS capgemini_academy.bronze.fifa_world_cup_matches AS
SELECT * EXCEPT (_rescued_data)
FROM read_files(
  '/Volumes/capgemini_academy/landing/files/FIFA/fifa_world_cup_all_matches_1930_2026.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);
