-- %%
CREATE TABLE IF NOT EXISTS capgemini_academy.bronze.movies AS
SELECT * 
FROM read_files(
  '/Volumes/capgemini_academy/landing/files/movielens/movies.csv',
  format => 'csv',
  header => true
);

CREATE TABLE IF NOT EXISTS capgemini_academy.bronze.ratings AS
SELECT * 
FROM read_files(
  '/Volumes/capgemini_academy/landing/files/movielens/ratings.csv',
  format => 'csv',
  header => true
);

CREATE TABLE IF NOT EXISTS capgemini_academy.bronze.tags AS
SELECT * 
FROM read_files(
  '/Volumes/capgemini_academy/landing/files/movielens/tags.csv',
  format => 'csv',
  header => true
);


SELECT COUNT(*) FROM capgemini_academy.bronze.ratings;
