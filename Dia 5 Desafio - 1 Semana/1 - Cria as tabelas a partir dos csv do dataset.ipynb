# %%
# %sql
CREATE TABLE IF NOT EXISTS `capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho`.bronze.products AS
SELECT *, 
  current_timestamp() AS data_ingestao,
  input_file_name() AS arquivo_origem
FROM read_files(
  '/Volumes/capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho/landing/files/Indian E-Commerce Sales Analytics Dataset/products.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS `capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho`.bronze.sales AS
SELECT 
  *, 
  current_timestamp() AS data_ingestao,
  input_file_name() AS arquivo_origem
FROM read_files(
  '/Volumes/capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho/landing/files/Indian E-Commerce Sales Analytics Dataset/sales.csv',
  format => 'csv',
  header => true
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS `capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho`.bronze.customers AS
SELECT 
  *, 
  current_timestamp() AS data_ingestao,
  input_file_name() AS arquivo_origem
FROM read_files(
  '/Volumes/capgemini-academy-challenge-LuizClaudioPinheirodeMouraFilho/landing/files/Indian E-Commerce Sales Analytics Dataset/customers.csv',
  format => 'csv',
  header => true
);
